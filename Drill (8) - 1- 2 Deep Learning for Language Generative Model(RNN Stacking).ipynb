# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
# %%time
# 원본 텍스트 파일을 내려받아 파싱

from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import numpy as np
import random
import sys

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


path = keras.utils.get_file(
    'nietzsche.txt',
    origin = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기 : ', len(text))

# 글자 시퀀스 벡터화
maxlen = 120 # 60개의 글자로 된 시퀀스 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스를 담을 리스트
next_chars = [] # target(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])

print('시퀀스 개수 : ', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자 : ', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리

print('벡터화 진행중...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype = np.bool)
y = np.zeros((len(sentences), len(chars)), dtype = np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1  # 글자 one-hot encoding 하여 0과 1의 이진 배열로 나타냄
    
    
# 네트워크 구성

model = Sequential()
model.add(layers.LSTM(128,
                      dropout = 0.2,
                      recurrent_dropout = 0.2,
                      return_sequences = True,
                      input_shape = (maxlen, len(chars))))
model.add(layers.GRU(64,
                     dropout = 0.1,
                     recurrent_dropout = 0.1))
model.add(layers.Dense(len(chars), activation = 'softmax'))
optimizer = tf.keras.optimizers.RMSprop(lr = 0.01)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer) # 타겟이 원-핫 인코딩이므로 categorical 사용
    
random.seed(42)
start_index = random.randint(0, len(text) - maxlen -1)
for epoch in tf.range(1, 30):  # 60 epoch 동안 모델을 훈련
    print('\n\nEpoch :', epoch)
    model.fit(x, y, batch_size = 128, epochs = 1)  # 데이터에서 한 번만 반복해서 모델을 학습
    seed_text = text[start_index : start_index + maxlen]  # 무작위 시드 텍스트 선택
    print('시드 텍스트 : ', seed_text)

    for temperature in [0.4, 0.5, 0.6, 0.7]:
        print("\nTemperature 값 : ", temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
            
        for i in tf.range(400):  # 시드 텍스트에서 시작해 400개의 글자 생성
            sampled = np.zeros((1, maxlen, len(chars)))
                
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.  # 지금까지 생성된 글자를 one-hot encoding
                
            preds = model.predict(sampled, verbose = 0)[0]  # 다음 글자 샘플링
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
            
        print()
# Out:
# 말뭉치 크기 :  600893
# 시퀀스 개수 :  200258
# 고유한 글자 :  57
# 벡터화 진행중...
#
#
# Epoch : tf.Tensor(1, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 384s 2ms/sample - loss: 2.2190
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self be as a stine expetion of the senfore and net the semplate of the and the sence of the has of the and a well the all as as all as the restent of the suffering as a come the stroind hose the last and a some his a deest of the spire of the such the and soned the extering concome of the same the neting and and as the cant of the concersition of
# the some and and be is not the sexperpesion of the ex
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seccise excomponture of a cost the
# rastion of the some he and and extationable of the excerent. the excers the suffer conscionatice of the such a concopsisition of the cention of real thin he sence and as some and as the excestent in the exconcession of concontioning the sime and all be instord conturation
# of the say the concession of the canres of the sespont of the states the exconture of the for
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# selves the exence of happead that as a to conceration of the ere for owion this he seffers the a beer man roms and a mice which a desing of the exconice of this sours, the we has all
# which he presences that is the deapost over
# concoment and are at
# a dirition the and restent of the
# well the
# real come with the mank as this
# exterited though a concarition opter the
# both that and excession of the seffoct
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secreapes, the doef ever is ode alw sundon and were the same
# of bat
# comict its the cealed muth a gentice. they orde to be great of
# the excerson the
# ginoto ade one chore and shative and
# we of the sect of the sapmation of chile if the symposelosing and is and the speriate and seect of the semply bue the exertarity past only for has ach the somate of the and has the fure his restion and and some and as
#
#
# Epoch : tf.Tensor(2, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.9038
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sentined be some have himself of of a condicult sense of the concections of the become of the some that himself of can to conceriently sense of the discurture and the condect of the precires of a concipert, one and to concioure and and and the self--and more and self of the more self--and contercious to the meally and the concertion of the encerver and man of the contiments of a conciperation of the
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# securing of the self the cand and concerolly and prover and concertain to searness and and prover prevility of he discome of the langeract and love of can and really and is as himeation and the gind to much instind the man in the man invillicultion of contill of the decimence to chan that that the and in the man the man and man the dight of more with more intention of mister concioual more and man t
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sends of the head virition the cause of the self of the
# self sense necession and recasition and a qually would verier and with a time of the spirit. the such the beconds to sensual that the call cast of the religion to all of more been the latter such the sense of a person and condence of morally, but who vertually the "mander and an importain man all domanding, and portounded must cause to concood
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seffectly and comans? which have be sole, in the poverially sime are and the jecially in the influally is himself the pistain him of to
# with robluse in the sacoticed but
# the conciules
# only sends of spording of god takent all man the man and
# faccess of belies and may he man the from not of its sind, and
# scill has dimpall that and say,
# the condection of can the genuibe? in the is such of such and ract
#
#
# Epoch : tf.Tensor(3, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 384s 2ms/sample - loss: 1.8284
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seeus of the consequent and world and compleate of the science of the hould in the serves of the good to be and of the most deserves of the spirit of the great of the preases, to be one of the world will of the concession of the deperion with the great world of conscience of them as the great of the good one of precessions of the world to world more of the god and to the sense, and strook of the dom
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self be to be most be the has the precises and every
# could, become and stolled of the gould of the great and conseble,
# more to mankens of the destions of processions of growe of the well to be the relige to the dastions of preto before and and live spore to have and most he general precirtion, who conscience to as a precesse, and knowledge and to be would of conceives to he not be were most not prec
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self of the world men instording of us we one conceives, in the most all stroge of proves and
# the good us as love the servess for he would the sull of the been science, to be of the most be science, who
# world of the possible of who an the goiness of the become and presences
# has heads over most exception, to could to before we world in the gord with and to precessions of freot for the does sunger sho
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-of commadance, of the gorisness to be one consequence, is to event conded, the mysself, to well of the interperious of the consequiness, of coll very bet all possible, it some
# good be seess, the acts, the stenes as exession of the conception, and man not would to and
# good amost of farse among; "who hons goous of the poweness, and one was of the like who do scolf we least, the restiven the hell
#
#
# Epoch : tf.Tensor(4, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.7911
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seeks. the harding of the has the be and pleasus of the himself and becape the has spectives of the spirit be the present its in the prosice to the conscience the cause as a has a mediestity of the was the will the heet for the
# xistress, and
# the
# dester of the has medies and despect and the cause he was the have to they cause to be the which the spections of the capal the departice the capress of th
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seake as the himself as the warticistical will let the spirit last the chartical towards--the hard, it is the spirit of the
# partacity and
# mack of the
# deligious from the dispection of the dividual helling the self-crearing as the sharture the spirit excession the awe ware the ward pasting the propes its such himself--perhaps and cleasus. the have the is from
# the great the have himself the
# harding and
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-chargures, certainties, considerents where deligious he certain how a
# have as the himself were a man men. he which the heart--the here of
# caust acts of us syme experience that the his owr-such they wreceasured the ciest the strongs are and
# stransed the
# greats extence because and
# conscience and the its and the fact as the
# cance of the conscience to the
# inscience inder which the world spection. t
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seventorian that the will
# the however the sedual spirit the who continction. the conside the will partion and
# the of the german. the
# scholled he he must pleishing the experative that new evedy mistion the chard the which the
# disturtian mandithing the whike
# the
# prise has will pleases effection and feels, the scholock, despective with the willing to the by are mestactions, as expetion. the what is the
#
#
# Epoch : tf.Tensor(5, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.7612
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self and the conceive of the mankind of the reasontary to mentifiess, and soul of the soul of the every here have be rest and soul to a served intered to the promestion, in the who one be soul the senter in the sense of here that the spirit and the sender of a sense of the enture here of the be and to a sense of god the great the more have the are of the soul of a concernained and complete of the pr
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self that he conterning of let of the fament
# the philosophers to the resting the restine and every contermation of the proses of the destines, prefaring to a tanding to the
# believe and of the sense, the resture to came that so learned and self mankind does be not can and the chust be are to be does and probler-many and power and resulted, and menion, and self be love of the world of the sense of the
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self of the compression and every self only and be supirition for their believe superiar is not of religion, and
# a fered sinder, that self of mankind and restly and for of the resting and sense of all their respon of a posority, and be perhaps how the sendament, because in only and betod the and so the resting
# of be seems a betare the restial course of all more self of meracise of have seakes to hak
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self--but its ristian adosians, what all that a realotes of their adonded and are sout deporement in their rather are fathary of who distermanter, the so instandered to
# the completion over, and shound here us there has hertials,
# and a will beings of sunding of every physate of action, and arrounded as a be sympathy probounder to antired that it
# all the garded of
# dest and for the
# hearled it, in a spi
#
#
# Epoch : tf.Tensor(6, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.7424
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense. the senses of the be a constance and and for the fevery present in a strength to the would advan be the such and who has deep as self-conscience of the prevent to the does a personal for the devel and be the present the world has a such a fulst of the world the subject the present what is an under the such the same as the same and from the far the for the conscience, and a personal called and
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secures and the consequent to present good even to the man the means of its a present the will will what is a man who was we call in the disciest and and
# of the consequent of the simple, at the existence of comparded, and man
# in the sense, and a most as of the suppasion of the conditions of the faination and not only men at past to the sense of the simple, and which the metter to dangerous of the de
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sender best will exception of the general
# from be would be interman from the same, "we has now who would
# standent "furselves" of a present wish the man in all the condition of the far the fund and the same even of betreantarded the conscience, the purposes the deration in experience and fanth of a sample, who would contract and science of the pain and in a man a consequence, as it is man of individu
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sextent will whereon still, is the spiendary that the loxed of cause its were find to the purited who sears constrong which the general postent denised conscience, the case the love chart of certain be will and compurius, and in that one would of "pease of the man one and them could contradition is a man, what is general to place philosophers of the many as a racical men and will be such and wishelv
#
#
# Epoch : tf.Tensor(7, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.7267
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seem and all at the great the such all the gradure to be all the fact and all the present and more more to more and all the spirit and the sumpers and all the such among every not will a command and all all the priment and all the state and all a may as the express and in meniated and and like and all with the subtumism of the same and not of the sense and been enduct it is a such a says and and is
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sech and the present and with a more more to miself and in the sumply called all a sumply fatter part to moral as all the best more all the freel to the act and will and virimed among to metaphyches in the such the sense and to men to the serurious to such a pastice and and different with the sumply as a such as and all the world as a however itself and all and
# now doom taste of profore all commandi
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self--all the test interecacts to as ethilly concealist of the spience and
# a present as else the
# sureter the
# most state a astent
# in the present with one state man agemance the instance of the will of all the superious a commdender and power, as men and opposed and alsend as the good to the
# conduct and impression and the sense and imperience, evil in the sunself
# of god,
# betray wemachical
# perhaps, him
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-prefound present it have as the have,
# a place and of self-mankind and these tenduled manifations alto, the astent be the god to the
# vidual common well as the spirit act and stranger itself to all all all a most extence as accomparent, and
# the tolution, the sunser ane
# time and says as east of perception and oppisions that that at the embiled, present
# in itself and faired and serted of him and fi
#
#
# Epoch : tf.Tensor(8, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.7159
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-conciples of the devolual for the religioning of the laters of himself have present morality, and the grature for the advance and for the word from the success and presention of a world and and the furthels
# of the existence of the same and conscience and
# conceptionable of the religion, and the complection, and something they conscience of the develogical the men of the present of the religious
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sensumal and the fact of the spirit, from the conscience, who has be the experience of the general different of the power for the precisely become from the facccuring from the complucism, the cause and the generation, the most chand and of the conception and complet which can not self and its exception he compreciation contempless of every obeding to experience
# and profound in the man and the higher
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self in the belogh and be be and could the complearion, the conjust there are the fines and bith comperience of the supposed present of a most now have not an at the happine.
#
#
# nty and it is a place and eurecher of crects, himself from the imprecisely every be be should centens of the word as one sensens to be the find: the most the circemon, in before
# crave morality, the strong of a dominace , to s
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-certain man proman moralotion.
#
#  gant make it is perhaps the warm word every now in a hatts and just of the men fasuring be the sable intenture not complenation of the possible who contranicaclity
# spirit and most
# crecisely rant of the engrequent of much something the circurrely of the wandered and sevount and certain his one from himself in the fiture and decomplet to morality, in the hard some
#
#
# Epoch : tf.Tensor(9, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.7080
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self are and such and as morality and discreate of the more as a morality of a moral are and grasment of the subjections of the soul and and casible of the formeless. and was as a morality of the spirit in the inventure of the most does something as he is a more not in the must the truth and conscience of and as develogical consequent of the not of the end or and be a man as a more dominacical world
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self with such the deserves of as only of as at perhaps the doment of the contrality of the
# long of a world according of the sussion the object in a contractical conjuct or the own has as propessions of the doman and france, for the only as a danger and conscience of the according and is and with and certain and the from the formant as sum and and every morality of the simple, and consequent, and in
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self of europe? which is all the commorality and court encaird aurity, and he only the farm. we
# long would be all and takes it was even this fermons of the
# result of which all romanting of his form the
# origin and roses and and soul
# in the ase as we has as which is man has in the such we and morality in the every essect and sympathy from a by interrous and late of
# the fiss morality, which is the ever
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self to own itflookantasistful, even doment of the same we to has involution to a game, with the europer, we rope of which all its intenlient with extranged of anmore from the such and contimilitic his the value of the nor in the precreall is condiction which exknowledge when it is it is nowarded; but them with a morality--precisely the excemplew. when is is the own as he most morality of explantion
#
#
# Epoch : tf.Tensor(10, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6972
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self--as the fact and all for a man of the problent the instincts and the engless and the most be a fact of the enther and in the feels and a probled and a man and in a generally fore the more for the conscience the will for the destruct that the conduct of a man fact and was the former and adors from the man and present and our some and a man of a man in the best and for the enther and a more and p
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense,
# the responses of the acts as a precience, its influently the est he are as the progress that a many a god the great and art of the heliging the more for the general intellect of a general man is a sake that a so are present an intently and do the only the genere the comment as its into the are superious feels the supposion, and in the wrost and in the superious and the tender and mankind and
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seaks was in the ets an
# in the superious
# and be attemptical cause of instinct of long decest and deep a more frinct accard us it as a degraining inflound upon the present in the fact the choins of our encheligical many opensible of encheless of the more nother always of a sore in so the warly faith and his main depresent catating the time and more the cold as a for a characity of such a morality gra
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-caraly and not of the generally and doal fainh as a cursimely the man as the many to and perhaps aflers in the own athards of reversian orgen in a not the instance from the "pines to best all hard drood in the sensitions and the happiness of the mask in become the regranged and for a power, bothing and at a man for the lager. the thing accord, something
# presences and in philosophy and all the e
#
#
# Epoch : tf.Tensor(11, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6922
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-conscience to be present the something of the valual to the more the present and best in the conception, and the inference of
# the man and different of the sense to the morality and the same the morality, and the man the mis the bad to the strong the command the modemal and compress of the same have the conscience to the more and soul
# extemption of the good to the philosophers have he the consci
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self means of the man to the world he conception of the power the moral to belong and the intermanity of the moral extains to the world to there one's thing to the superiod of all the strength he could sense of the
# long the extance to the forly are the hold and the belief the sensible, and feeling to the conclusion and there former and in the
# stands and any conception and the power to the commanity
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self--formed to the power to be the harder that the philosophers of should the world, and the man been that the to the more and a more merely of the dangers, the modered and
# to the freedom. there is the injustically and
# wish, to our articality of the conceptoon to the schoed--not one mankind the partic hadd of any world of the can been conception, and happined to perhaps he has and the man of the co
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense against that the whole the conscience, which the come--for to thinking too as the more not is to be alweads feel he present be conscience conscience, for the old in morality of suphords past of evilical contemption of been morality the conscience and become tencipialied of the conscience of the compossible, and the forman something
# expection of imponsible of they to arterminance of something t
#
#
# Epoch : tf.Tensor(12, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6850
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self, and and self the pleasure the sense of the senses which he in the say of the distingtion of the attended the sense of the believe the same the reason the happiness of the fact of the most for the lines which the sense of the one the findly the spirit of the self and discovers the most as in the present and the great free the world reason and for the mode and souls and the fact of the fact the
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self the religions. which the sense in a metive
# in the sense of the himself and the sense of this the centures the who sense of the domant man as conduction of the called of the will time the discience as self to the
# sense the necessary love one reason of virtue; and and all the not in experience the faith the most the sense, in conduct there are state himself and sympathy of all scestion of the wil
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self call the sunself pleasure the senses in the self intelling, in the endured discres. and not mist of any as the religions and himself for the disconception of men, with the child more in the suld manifest into the conditions which for able desponsible into a plato common of the possible the most reasom of the
# seems and disting of most be
# self from most despines that seems of
# feelings to this sci
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense the factation and discretate deligions of his would not "the "who "the "woman"
# "the god," sgeve him the exense and and live experience of the god. his former one the religions in so cline the restrowledge, which which he general cree himself this strition of mith strength of the super adved by the finding, but which he all rulping into himself men the and and that the must centation of find to
#
#
# Epoch : tf.Tensor(13, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6790
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serious intelligions and the conscience of the proful the construct of the consider in the construct the construct of the present to the fact and perhaps the profound and consequent the higher and that such a consequent of the senses and the some man so the such the manimation of the suffering the subtle consequent of the consequent the compleasion and all the consideration of the man the consequent
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serring to the varity and make the respect to the supposition of the example of the experience of the grating and deal the great manise man of the such the consequent of man and the present the construct the contemption of the considerance the spirit against and empare in the conduct the far that one crasted and has such even of a new destance to the cheritions in the consequent, and not be suble de
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serious indefined one of it is men
# the most been contemption. certainly appearisting the discration of conscience of the words the present men of conscience of such the state a discread, the crastement, it the edeverse intered the could to like for which he a happess of the sacrustion and
# consider they and constinct, to the compurity and for it might of this ill we all the self-spirit to the consequ
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serficious with repart be the real case in cilled in the ears and self-considerous the proppessiver of a peasing
# that with
# metortic connitually virtues, or philosophers we have with the
# bagises and dimand, the simple of the slau of the propritions of this indifferent of the charpanity.. the will all and means of the rused of the consequently affered and constance of the science in the confections ar
#
#
# Epoch : tf.Tensor(14, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6728
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense of grate with the sense of a individual and conscience of all and astrance, and a something in the same of the world and doubted of himself of his not and reason of the sense of contradication of a something in the point of a something and virtue with any in the preciunsness in the man a promper of the stronger of longer to which is as a stronger of all is it is one of such a perhaps and the s
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense, of the despect of the strange of contrady to the most philosophers of the strange of its the result man something our in his descrumselves of men and are the same the world, and wishoutand more more what is the such as the for the bourages power it is something with the simple cause the more one with the love as the more into the lasted to restronge of a propers of the prives one of a thing o
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sensed--so
# some the servination of the will it only with a science of general and many with the refained the contradse of contrass understood of a some history in best something in the prowerd. have one will the great one one to the sore of that it is with the something a feel and priding the sense and old encersality of any a not incogning
# one with a philosophers of any conceine of not so are more
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense of also rous with its occustical frignce is and verecher of a  amamon with a good beforeing the love the preciplicanity." one with man possible is
# probse how is only and itself, in the origin. but what is those one with his sort our into not more is it is not of a light not with the world himself its fine of us:
# which we passion who our on what is, place one was a will they protence, other in
#
#
# Epoch : tf.Tensor(15, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6707
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-power that in a suffers of the belief it as a man the world as the deligion, and not be man of with a the propense of the instance and instance of one all the problect of the present despired and more the are such as when it is man which a long the same to the dest under the suffering the present who destrugn and the strong of the pains. the present in the world and fact of with the contemplati
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self degards and the imment and latter to a will the very a factions, when the perhaps decession and man contrairty of the profound that which means of proble and and lack and the truth the suffer the will the suppose and suffering to the could nothing the understand we man "woman in the patters more the same and "the "from "free "the "and "the "influence "for the fane there is a "suffer the scient
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serve of many should be most undividual placite, and in the conception that it who is man--and the fact and soul with the refendation of a science what his deligion himself in all present the as "it we "woman "the "strangely and "interent and venture" and such can the give to conception of the for the german believe and the gratment and to the sufferment of the more sense which and rations with ever
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self of the promance to one is command doing the before about the religion the conduct to ane an a restrange incortly of such a more one and perhaps in life and at perhaps been in the truth, in in the detellected he can understand of interpendance
# of deport, and to the preficticial inspicity more the belief
# the falses to new all more gold subject, the "thoughly "effects" of with which
# supparation al
#
#
# Epoch : tf.Tensor(16, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 383s 2ms/sample - loss: 1.6661
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-man the spirit the spirit of the compares and perhaps and complates with the conscience of such the believe the suffering in the spirit and for the spirit in the man the instincts of such all comparered to long the world come the general or the desire of all and this emhance of the spirit in the person and the spirit the sense the consequence to the comment where is in the command to the spirit
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-comparted the
# world perhaps be mankind the spirit and the well a strange of the
# emphysical feeling and suphartation. the spirit who will to desire
# to they soul why are with the come the spirit and the more perpanition of christic in the more spirit and something the personing is the personal is as man and in the general the world, also the heired in the believes to consequence in the lateless t
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seeks when a great to coming consequence as the state are men of consider of the believe and such are in german, himself when a result more among of more in that they had the
# arter. the christian, the world be such they man was as a rach men the who are present, they knows he is be aught of the medietions and the has there one should be a perhaps the
# probletive of the despect it is he the profounds
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serie and perceptive restility of man: the
# sense, as to the apone bestive. they has always suspect and its more learn the command in among and suffered, wishout of the chain same
# always the longers of of the
# elrection in distrustive, himself. the emotion of bould short of is in the soul at also decest to consister of a
# moral own schope
# in man and anyon the great and the worth conterility with the wh
#
#
# Epoch : tf.Tensor(17, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 384s 2ms/sample - loss: 1.6605
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense the sense the present.
#
#
# 1
#
#
#
# 1 much the greater to the stringer the gradually and in the far the like to the sense of the degreates and the feeling and and fained the fact the free and and the philosophers the proves and the be learn the same and the instinction and the deceptions and the sense of the proves the propers of the distruth and the spirit. the believe is the own and to the faith a
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serving and contral, and the mens of the proves and the interious stand and intellectual period of the ears of the times things and the from the have and certain to the fined as and cause the first the interpression of the entification and the mans to man and it it mankind and seak the supplined to the provely of the constinction of the "from "the "day" "and the "the bedief with its own seeks of "th
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seekless above he because whole the refined the from the one and himself back it the do the fact moral to be more man and as the capack and victure, and as the bad be it at protestical last all the entigoral are and the constray for the feres the belief it so time and the funally power and the first of the same and the same to men and it and revelops and the readon and this according and christian a
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seff to the eneasted in it the prople secrarism and philosophy--as i one is the soot to the flient and the ructical constraating interpation and have names men almost fair the sympathy
# in the word, the proper the emplann--intelletion with the prohest to which the feeling, which for the regree a present here deside hitherto the nairy pertical impoint and take maans of the precealed of lave to a displ
#
#
# Epoch : tf.Tensor(18, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6569
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self the more of the suffering is that only the prodution of the more perhaps a more longer and the most in the more the more man of the most and man the more and and and the consciou man and man of the conscience of the moral profounds of the moch of the proved than in the sensible of the modern of the endure the advantion in a much the most more moral the the possible some more not the most the vi
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sears and more the self the compulsion of the conception of the precise moral former and real in the recovers of the words and propound of the most mind of the more and the great most the things the more and understand and and of the more to an way of the great must of a more more and into the whole and their modern and demanding conduined the more the world to his our possible, and the one and inst
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self, doing to responsible with the world be in the mole of expression of the seims and some more of the more moral pain, and precise of the more man of the form of the most present of which will the pain of the most be the constrance
# of individual the question in the expelling of moral be world be higher possible placity loves and so endure and are europe. power things soul of the conception in gre
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secommest and me earth of the faculty, and thought of manifous, of by the fare in things, the only and paining in the instinction of experience to a thing to any religion and mrounity of the perhaps man himself, the accorders of faction of be the thing the moral truth of conturity of one he schoolo of the divines and power of with the complation of fact the more, possible to palming against law of e
#
#
# Epoch : tf.Tensor(19, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6553
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-grows the spirit the dest to an antithing the experience of the stronger opinion and and the present to self-spirit the self-contralurity and
# the sense the destrution, and the most conscience of the probleme and the strange in the contralation of his acts and the philosophers and understood in the possible who who destrust of more the man the degele the conception of the would be all does the s
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-spirit of any and possible of the suffers in the would have to all the strong and all the world and the extent, contention himself the most person and the consequence strong of the enther of life and destly on the would be one who would new stranger the great expleasure the dangerous reason. the general the world which when a most self-present chording as one and problem to the domance, interpl
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-breaks in explosited of the presented
# with the same moral will as intellecturality and means would be ancience as the rawher is he has const
# in
# the possibility and an enterrance of the world into the man expression, it was order to one and reason there is for
# conception of men. the has to exemple, which the prowerfounce in a complay the other, constinctions the self-sunjust perhaps period regar
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sercise, and demontain the power god the once best who does become simplay unto the honch--the most spirit the pution, they would be the believe the constance, the readher as
# and has bood in himself understand ploseing attainter and intellection of simply consequence as perhaps the
# pantion and understanding in the however, and percomposing dispossible the tainty and how as the same without can phelo
#
#
# Epoch : tf.Tensor(20, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6532
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-condition of the germans and the present the stumpless of the consideration of the pride that the could interpose they are the stand that the will not the states that every promance to the world would the believes of the present and the world in the common and althere states that the last the general precisely and the concerning the conturing to the concern and in the present in the command and
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# ...
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seate, to our most instance of super-apperent the supposion, and intention is a think it is to the interposedical of the right morality, there are to the extance, as in the spirit of its with it comparent of
# means, at the same of belief and advant, or serious do not and neberted, is the things with the will to the same in the hard, in the good that and a generally experience of same in its necessary
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sereptionists in the sistusions, with everything, spepards of the other and togar of they in a soul, and the god, and are have a good, as that he soul appationce and belief as every actually, and is result of a manifelogication. the instincts of this consequent, explained in the other, that is judge to signed to it ease
# and every other, and great me seems
# manner of the immaniantiness and as present
#
#
# Epoch : tf.Tensor(24, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6434
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-moral of the all to be fact the world for a stand to the science of the power of the being as the same in the interpossible and the are the invention and of the pirture and for the seconded and the assument of a self-gradution of the evil and all distorted the reason. the power of a such a perhaps i soul the possess to be his a production of the profound the still for the are a the conscience i
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-thought of the pain to read be profunds to has not not no conscience, and the comportany solution of the respiction, as its powerful the god to be the propersion of his power the same and all such
# the advantifical problem of the same souls of the conscience, where the same not the being and consequently, the most seems and the stupid possession and reason to constance in the former of into stil
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-disgumonistic
# things all the require the should be considness the problems
# of the to and importans, all the every only the german can pain, the blorness and loft and subject its all distording become
# should be a burged every says, the all is who is the roped of the considence of the things and equally and a spirit to sympathy for the impossible, the consider the spiritual moral of the power thi
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seems propision the extrays to lifeous against the such all regards of the condement of the sensur in punists of such dejudy consequentures of the best morality, the result. the string all in the subflection of the hard of the consideration and compisted and the sensess of a stand, the interported which the should protuct ging that not love to his the consequent--bod
# as the have case to a be still t
#
#
# Epoch : tf.Tensor(25, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 383s 2ms/sample - loss: 1.6392
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-fairth and former to sake of even to determination of the rangerous profuction of the same the considerated for the more and and enthing of the servicient and man of the long of character of the man of manifest in a man and any the possible and the struct and same of the desire and the conceive and for intellection of man and that in the such been possible further in the fact of the changer to
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sensible of his dangerous and this experience that he has a whole and comparion of the most conscience much in which is the science of the self-such the world and of the present to be characted the intelliction of belief that the comparation of sack and individually and different with a such a sincher to understand to not god in still the individually and fears of men of the proment and man of the p
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self speak for only an ame which was so more will not et on a sensible to itself in man of the spirit and for the predicistice and and what is any more our acts not man for the belief because and
# conscience of indifferent compuntive long something the faculty and and are
# any will for the own deligion of the same and for the present and comprecisely will the maniforman perceive in morally the world p
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-madically god with the nature with the more former and can former our perceive, and more intellacification of the world be
# man to the dest every xist and wimher openate for moral
# more to himself by from their furthure power of the comparenic
# call promand and with in the deficult but a deal the .r
# act i should be the power what is all the faints of was into actually of the great individually can
#
#
# Epoch : tf.Tensor(26, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 383s 2ms/sample - loss: 1.6359
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self and other, in the conscience of such the man of the conscience and are in the subject there is not not him and and entiled the except of the spirit of the more self-thing and stronger here of a serience of chained and which he seems in the sense of contradity when the man and in its the stronged to heart upon the reading the more the more not be all the man and self the whole and conscience of
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# servined man them in the will and and the character of a changers and
# instincts of a men of the sense of the will the means and shart of the conscience of the world or believe exception. it is the more in the series and in the man and ages of the world now to the
# sense of the amparished in itself and interpreasion, the moral readent and and and first seems of a mere and man taste of the immed in the
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# serves, were to the conduct mind in which the midds the metaphysical conscience and read to hour of purhas in the world dusion of himself of the more really have really be chere with a snould looked of himself present of the men of man as mentiness and great earser perhaps the spirit in the finds to the means in the seems to the demormed
# of belief our delicable the supposing and
# into spet through th
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-word: wherever one mave of the more no many languight something in the express in the more as they them have disconcession of the origins, or the wup of intermons a necessary of them for not and little is the spirit of we arrown have been
# begreses, conscholority concleated not only or this mankind and man and from me strimily repury of very regard be the except in the is and the more all though
#
#
# Epoch : tf.Tensor(27, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 382s 2ms/sample - loss: 1.6327
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sensible of the spirit in the belief and the most estempar in the deepering in the spirit in the soul, and in the commended with the contrary the decide of the most expression in the conscience in the proposition of the contrary in the conceived and man to men the will the sense in the immender and deception in the contration. it is in the contemple of the something the still which is the sense and
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sees a souls that which is enchild and a concession of the general who deeper in protection in the interpossible and problem
# to lack the once and the consequent of life and the spirit of the man of the contrary
# the grope and the metive the faction of a contempled of the indeed to the most so
# to the contrary things man of the lave of every sense to interpossess and the self-oppisice in a spirit of th
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# sense in the whole live protuss of a weak. it is be the spirit, it is is the suspectical was the interposition of things in the depacrical religion of the most original things in the precisely our destry and the strange of the own things of the incarding conclision wid of the sensible in the conditions is condect of his object here of the sensition in a
# man to one with everything pain and his opposi
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# seems the indevelopmentations
# by the can so perhaps, which a the serpossible a yesparse into the perhaps a whole have the deeper the charace, who spirit of crongerity as
# itself as
# the demind of his proved to the suscient of the into power of philosophys with the moralist pasting of an
# ay something its morality of cuntration there placed and his sexpethance interious however end a morality which go i
#
#
# Epoch : tf.Tensor(28, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 383s 2ms/sample - loss: 1.6306
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secures and the possible and of the still necessity of the finest they all the such all the extract in the concerned the first of the success and all the existence of the spiritually not it are the problem and all the fact of the conscience in the success of the more to the else of a things the existence of the possible in the dealing the reader in a live in the are in their perhaps perhaps the fals
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secience and of the conceive of the faction. and all the free spirit the consequence of the superis and of the possess of the
# extence in the concession of the being of in the existence and present the properses in the such the dividually interilation of the love an and case the same so fact to which in the experience of the power the greater success and the rome the really the bround of morality at
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secrection and as the belief the contrary present and the infinerient in the expressions, the condict of the spirit to domence precises upon all possess of the such present man any seried in the concerned the honed the
# concernal to himself of child it is the present this diever which in the development and secience of every sports which more distoing, every more particity, the hunition of distrues t
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# secures of a postence. he with the creation in a command with his opposing of every his opposing them with all the such an all the present this metaphysice the posses and prejude of the contemption. he may make a seems the success of the world in the great profices to a
# superess in all this possible the definiving its origin of all their fores being we interprecialing are they are his being the how,
#
#
# Epoch : tf.Tensor(29, shape=(), dtype=int32)
# Train on 200258 samples
# 200258/200258 [==============================] - 381s 2ms/sample - loss: 1.6332
# 시드 텍스트 :  the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# se
#
# Temperature 값 :  0.4
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-may a such a desire for the acts and spirit and the possible in the nature and still a strong the think of the more and and something and his of the state of the same and man and of a such a state and on the same and and a our actions of the spirits and and such all the own such a such the strught and with a german and desires of the sense of the supertions of the present and the are new and va
#
# Temperature 값 :  0.5
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-may be
# deceated and the strught and and and the simpar for the stincts for the reason and soul as it is present favour and as with the state and sunsest of the actions and the extent and understand with the speciality and one all a gaint with the actions and the are of the on the spirit and spirit of all that the profound the way and the constance of instances, and one and self-distrution with
#
# Temperature 값 :  0.6
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-yea of life of the gards of a matters and on our adotiments of comparity of a of the great most exent all the own instance. have he does blect of many may a degeniate as the grow with a before and a distused and about the concession of the sense of the among and good a distent and vatural and and not and nature of a mander from the great and among homach at the astiment thinks of our will of re
#
# Temperature 값 :  0.7
# the slowly ascending ranks and classes, in which,
# through fortunate marriage customs, volitional power and delight in
# self-stries for the more must the cade and lait even with that soul, and the present attemptions it is vigively  new new other and desirimed of their existent felly according of the god of the
# ready the strositions) and laboured troughts and least of the last ummoral axpreciation
# and freer how among that has general mer some
# opposed with to as feel detressions and fart and some as miderful. the same
# CPU times: user 5h 42min 49s, sys: 11min 23s, total: 5h 54min 12s
# Wall time: 4h 9min 48s

# %%
# 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
'''
다항 분포 샘플링 함수인 multinomial(n, p, s)의 
n은 샘플링 횟수, p는 확률 분포 배열로 전체 합이 1이 되어야 한다. s는 샘플링 과정을 반복할 횟수이다.
n이 충분히 크면 반환되는 배열의 분포는 p의 분포에 가까워진다.
이 코드에서는 n을 1로 설정했기 때문에 (샘플링을 한 번만 수행하므로) 반환값은 하나의 원소만 1이고 나머지는 모두 0인 (s, len(p)) 크기의 배열이다.
'''
def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# %%time
# 텍스트 생성 루프

random.seed(42)
start_index = random.randint(0, len(text) - maxlen -1)

for epoch in range(1, 30):  # 60 epoch 동안 모델을 훈련
    print('\n\nEpoch :', epoch)
    model.fit(x, y, batch_size = 128, epochs = 1)  # 데이터에서 한 번만 반복해서 모델을 학습
    
    seed_text = text[start_index : start_index + maxlen]  # 무작위 시드 텍스트 선택
    print('시드 텍스트 : ', seed_text)
    
    for temperature in [0.4, 0.5, 0.6, 0.7]:
        print("\nTemperature 값 : ", temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400):  # 시드 텍스트에서 시작해 400개의 글자 생성
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.  # 지금까지 생성된 글자를 one-hot encoding
                
            preds = model.predict(sampled, verbose = 0)[0]  # 다음 글자 샘플링
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
            
        print()
# Out:
# Epoch : 1
# Train on 200258 samples
#   6272/200258 [..............................] - ETA: 12:51 - loss: 1.8585
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/.conda/envs/jktest/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# 다른 온도 값을 사용하여 확률 분포의 가중치 바꾸기
'''
소프트맥스 온도(Softmax Temperature) : 이 파라미터는 샘플링에 사용되는 확률 분포의 엔트로피를 나타낸다. temperature 값이 주어지면 다음과 
같이 주어지면 다음과 같이 가중치를 적용하여 (모델의 소프트맥스 출력인) 원본 확률 분포에서 새로운 확률 분포를 계산한다.

이 함수는 1보다 작은 실수 배열(original_distribution)을 로그 스케일로 바꾸어 모두 음수로 만든다.
temperature가 1보다 작으면 더 큰 음수가 되므로 원본 스케일로 복원했을 때 배열 원소 간의 차이가 더 커진다. 반대로 1보다 클수록 0에 가까워지고
원본 스케일로 복원했을 때 배열 원소가 비슷한 값이 된다.

temperature 값이 낮아지면 다른 확률은 거의 0에 가까워져 탐욕적 샘플링(greedy sampling)이 된다.
'''
import tensorflow as tf
import os
import numpy as np

def reweight_distribution(original_distribution, temperature = 0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

path_to_file = tf.keras.utils.get_file('shakespeare.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
print ('텍스트의 길이: {}자'.format(len(text)))
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1122304/1115394 [==============================] - 0s 0us/step
# 텍스트의 길이: 1115394자
