# %%
# %%time
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

currentPath = os.getcwd()
print(currentPath)
os.chdir('/Users/jaekunpark/Dataset')

# IMDB 원본 데이터 전처리
imdb_dir = '/Users/jaekunpark/Dataset/IMDB/aclImdb'

train_dir = os.path.join(imdb_dir, 'train')

labels = []
texts = []

for label_type in ['neg', 'pos']:
    dir_name = os.path.join(train_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname[-4:] == '.txt':
            f = open(os.path.join(dir_name, fname), encoding = "utf8")
            texts.append(f.read())
            f.close()
            if label_type == 'neg':
                labels.append(0)
            else:
                labels.append(1)
                
# IMDB 원본 데이터의 텍스트를 토큰화

maxlen = 100 # 100개 단어 이후는 버린다.
training_samples = 10000 # 훈련 샘플 200개
validation_samples = 10000 # 검증 샘플 10000개
max_words = 10000 # 빈도 높은 단어 10000개만 사용

tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('%s개의 고유한 토큰을 찾았습니다.' % len(word_index))

data = pad_sequences(sequences, maxlen = maxlen)
labels = np.asarray(labels)

print('데이터 텐서의 크기', data.shape)
print('레이블 텐서의 크기', labels.shape)

indices = np.arange(data.shape[0]) # 데이터를 훈련과 검증세트로 분할. 샘플이 순서대로 있으므로 먼저 데이터를 섞는다.
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]

x_train = data[:training_samples]
y_train = labels[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = labels[training_samples: training_samples + validation_samples]

# GloVe 단어 임베딩 파일 파싱

    #압축 해제한 파일(.txt 파일)을 파싱하여 단어(즉 문자열)와 이에 상응하는 벡터 표현(즉 숫자 벡터)을 매핑하는 인덱스를 만든다.
glove_dir = '/Users/jaekunpark/Dataset/IMDB/glove.6B'

embeddings_index = {}
f = open(os.path.join(glove_dir, 'glove.6B.100d.txt'), encoding = 'utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype = 'float32')
    embeddings_index[word] = coefs
f.close()

print('%s개의 단어 벡터를 찾았습니다' %len(embeddings_index))

# GloVe 단어 임베딩 행렬 준비

    # 임베딩 층에 주입할 수 있도록 임베딩 행렬을 만든다. 행렬 크기는 (max_words, embedding_dim)
    # 이 행렬의 i번째 원소는 (토큰화로 만든) 단어 인덱스이 i번쨰 단어에 상응하는 embedding_dim차원 벡터
    # 인덱스 0은 어떤 단어나 토큰도 아닐 경우를 나타낸다.

embedding_dim = 100

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    if i < max_words:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector # 임베딩 인덱스에 없는 단어는 모두 0이 된다.
            
# 모델 정의

model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length = maxlen))
model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

'''
# Pretrained Word Embedding 을 'Embedding'층에 load

    # Embedding층은 하나의 가중치 행렬을 가진다. 이 행렬은 2D 부동 소수 행렬이고 각 i번째 원소는 i번째 인덱스에 상응하는 단어 벡터.
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False
'''

# 모델 훈련 & 평가
model.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
history = model.fit(x_train, y_train, epochs = 50, batch_size = 32, validation_data = (x_val, y_val))

# 결과 그래프
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label = 'Training Acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()
# Out:
# /Users/jaekunpark/Dataset
# 88582개의 고유한 토큰을 찾았습니다.
# 데이터 텐서의 크기 (25000, 100)
# 레이블 텐서의 크기 (25000,)
# 400000개의 단어 벡터를 찾았습니다
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 100)          1000000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                320032
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,320,065
# Trainable params: 1,320,065
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/50
# 10000/10000 [==============================] - 2s 246us/sample - loss: 0.5191 - binary_accuracy: 0.7208 - val_loss: 0.3875 - val_binary_accuracy: 0.8264
# Epoch 2/50
# 10000/10000 [==============================] - 2s 210us/sample - loss: 0.1374 - binary_accuracy: 0.9541 - val_loss: 0.4327 - val_binary_accuracy: 0.8213
# Epoch 3/50
# 10000/10000 [==============================] - 2s 218us/sample - loss: 0.0106 - binary_accuracy: 0.9980 - val_loss: 0.5804 - val_binary_accuracy: 0.8248
# Epoch 4/50
# 10000/10000 [==============================] - 2s 224us/sample - loss: 7.9247e-04 - binary_accuracy: 0.9997 - val_loss: 0.7138 - val_binary_accuracy: 0.8212
# Epoch 5/50
# 10000/10000 [==============================] - 2s 232us/sample - loss: 8.2610e-06 - binary_accuracy: 1.0000 - val_loss: 0.9450 - val_binary_accuracy: 0.8191
# Epoch 6/50
# 10000/10000 [==============================] - 3s 252us/sample - loss: 1.0309e-07 - binary_accuracy: 1.0000 - val_loss: 0.9958 - val_binary_accuracy: 0.8249
# Epoch 7/50
# 10000/10000 [==============================] - 2s 250us/sample - loss: 1.3289e-08 - binary_accuracy: 1.0000 - val_loss: 1.0237 - val_binary_accuracy: 0.8249
# Epoch 8/50
# 10000/10000 [==============================] - 2s 242us/sample - loss: 7.6978e-09 - binary_accuracy: 1.0000 - val_loss: 1.0407 - val_binary_accuracy: 0.8246
# Epoch 9/50
# 10000/10000 [==============================] - 2s 238us/sample - loss: 6.2152e-09 - binary_accuracy: 1.0000 - val_loss: 1.0514 - val_binary_accuracy: 0.8245
# Epoch 10/50
# 10000/10000 [==============================] - 2s 243us/sample - loss: 5.5688e-09 - binary_accuracy: 1.0000 - val_loss: 1.0605 - val_binary_accuracy: 0.8257
# Epoch 11/50
# 10000/10000 [==============================] - 2s 249us/sample - loss: 5.2139e-09 - binary_accuracy: 1.0000 - val_loss: 1.0722 - val_binary_accuracy: 0.8236
# Epoch 12/50
# 10000/10000 [==============================] - 3s 253us/sample - loss: 5.1427e-09 - binary_accuracy: 1.0000 - val_loss: 1.0761 - val_binary_accuracy: 0.8238
# Epoch 13/50
# 10000/10000 [==============================] - 3s 262us/sample - loss: 5.0536e-09 - binary_accuracy: 1.0000 - val_loss: 1.0802 - val_binary_accuracy: 0.8252
# Epoch 14/50
# 10000/10000 [==============================] - 3s 259us/sample - loss: 4.9136e-09 - binary_accuracy: 1.0000 - val_loss: 1.0853 - val_binary_accuracy: 0.8242
# Epoch 15/50
# 10000/10000 [==============================] - 3s 263us/sample - loss: 4.8709e-09 - binary_accuracy: 1.0000 - val_loss: 1.0938 - val_binary_accuracy: 0.8236
# Epoch 16/50
# 10000/10000 [==============================] - 3s 271us/sample - loss: 4.8095e-09 - binary_accuracy: 1.0000 - val_loss: 1.0970 - val_binary_accuracy: 0.8238
# Epoch 17/50
# 10000/10000 [==============================] - 3s 273us/sample - loss: 4.7896e-09 - binary_accuracy: 1.0000 - val_loss: 1.1001 - val_binary_accuracy: 0.8234
# Epoch 18/50
# 10000/10000 [==============================] - 3s 266us/sample - loss: 4.8118e-09 - binary_accuracy: 1.0000 - val_loss: 1.1026 - val_binary_accuracy: 0.8232
# Epoch 19/50
# 10000/10000 [==============================] - 3s 261us/sample - loss: 4.7915e-09 - binary_accuracy: 1.0000 - val_loss: 1.1076 - val_binary_accuracy: 0.8233
# Epoch 20/50
# 10000/10000 [==============================] - 3s 264us/sample - loss: 4.7769e-09 - binary_accuracy: 1.0000 - val_loss: 1.1075 - val_binary_accuracy: 0.8231
# Epoch 21/50
# 10000/10000 [==============================] - 3s 281us/sample - loss: 4.7559e-09 - binary_accuracy: 1.0000 - val_loss: 1.1146 - val_binary_accuracy: 0.8230
# Epoch 22/50
# 10000/10000 [==============================] - 3s 262us/sample - loss: 4.7654e-09 - binary_accuracy: 1.0000 - val_loss: 1.1159 - val_binary_accuracy: 0.8230
# Epoch 23/50
# 10000/10000 [==============================] - 3s 265us/sample - loss: 4.7943e-09 - binary_accuracy: 1.0000 - val_loss: 1.1133 - val_binary_accuracy: 0.8239
# Epoch 24/50
# 10000/10000 [==============================] - 3s 263us/sample - loss: 4.7721e-09 - binary_accuracy: 1.0000 - val_loss: 1.1191 - val_binary_accuracy: 0.8234
# Epoch 25/50
# 10000/10000 [==============================] - 3s 268us/sample - loss: 4.7096e-09 - binary_accuracy: 1.0000 - val_loss: 1.1230 - val_binary_accuracy: 0.8227
# Epoch 26/50
# 10000/10000 [==============================] - 3s 268us/sample - loss: 4.7736e-09 - binary_accuracy: 1.0000 - val_loss: 1.1236 - val_binary_accuracy: 0.8232
# Epoch 27/50
# 10000/10000 [==============================] - 3s 266us/sample - loss: 4.7497e-09 - binary_accuracy: 1.0000 - val_loss: 1.1239 - val_binary_accuracy: 0.8236
# Epoch 28/50
# 10000/10000 [==============================] - 3s 276us/sample - loss: 4.8608e-09 - binary_accuracy: 1.0000 - val_loss: 1.1295 - val_binary_accuracy: 0.8229
# Epoch 29/50
# 10000/10000 [==============================] - 3s 259us/sample - loss: 4.7871e-09 - binary_accuracy: 1.0000 - val_loss: 1.1302 - val_binary_accuracy: 0.8230
# Epoch 30/50
# 10000/10000 [==============================] - 3s 276us/sample - loss: 4.8046e-09 - binary_accuracy: 1.0000 - val_loss: 1.1327 - val_binary_accuracy: 0.8226
# Epoch 31/50
# 10000/10000 [==============================] - 3s 280us/sample - loss: 4.7825e-09 - binary_accuracy: 1.0000 - val_loss: 1.1346 - val_binary_accuracy: 0.8226
# Epoch 32/50
# 10000/10000 [==============================] - 3s 277us/sample - loss: 4.7029e-09 - binary_accuracy: 1.0000 - val_loss: 1.1360 - val_binary_accuracy: 0.8220
# Epoch 33/50
# 10000/10000 [==============================] - 3s 275us/sample - loss: 4.8427e-09 - binary_accuracy: 1.0000 - val_loss: 1.1410 - val_binary_accuracy: 0.8213
# Epoch 34/50
# 10000/10000 [==============================] - 3s 285us/sample - loss: 4.8150e-09 - binary_accuracy: 1.0000 - val_loss: 1.1407 - val_binary_accuracy: 0.8223
# Epoch 35/50
# 10000/10000 [==============================] - 3s 291us/sample - loss: 4.7897e-09 - binary_accuracy: 1.0000 - val_loss: 1.1370 - val_binary_accuracy: 0.8228
# Epoch 36/50
# 10000/10000 [==============================] - 3s 285us/sample - loss: 4.7738e-09 - binary_accuracy: 1.0000 - val_loss: 1.1424 - val_binary_accuracy: 0.8220
# Epoch 37/50
# 10000/10000 [==============================] - 3s 290us/sample - loss: 4.7803e-09 - binary_accuracy: 1.0000 - val_loss: 1.1457 - val_binary_accuracy: 0.8217
# Epoch 38/50
# 10000/10000 [==============================] - 3s 299us/sample - loss: 4.7906e-09 - binary_accuracy: 1.0000 - val_loss: 1.1454 - val_binary_accuracy: 0.8219
# Epoch 39/50
# 10000/10000 [==============================] - 3s 285us/sample - loss: 4.7840e-09 - binary_accuracy: 1.0000 - val_loss: 1.1487 - val_binary_accuracy: 0.8216
# Epoch 40/50
# 10000/10000 [==============================] - 3s 284us/sample - loss: 4.7872e-09 - binary_accuracy: 1.0000 - val_loss: 1.1474 - val_binary_accuracy: 0.8218
# Epoch 41/50
# 10000/10000 [==============================] - 3s 279us/sample - loss: 4.7592e-09 - binary_accuracy: 1.0000 - val_loss: 1.1484 - val_binary_accuracy: 0.8215
# Epoch 42/50
# 10000/10000 [==============================] - 3s 292us/sample - loss: 4.7760e-09 - binary_accuracy: 1.0000 - val_loss: 1.1511 - val_binary_accuracy: 0.8214
# Epoch 43/50
# 10000/10000 [==============================] - 3s 289us/sample - loss: 4.7746e-09 - binary_accuracy: 1.0000 - val_loss: 1.1500 - val_binary_accuracy: 0.8217
# Epoch 44/50
# 10000/10000 [==============================] - 3s 283us/sample - loss: 4.8065e-09 - binary_accuracy: 1.0000 - val_loss: 1.1557 - val_binary_accuracy: 0.8209
# Epoch 45/50
# 10000/10000 [==============================] - 3s 288us/sample - loss: 4.8620e-09 - binary_accuracy: 1.0000 - val_loss: 1.1508 - val_binary_accuracy: 0.8216
# Epoch 46/50
# 10000/10000 [==============================] - 3s 283us/sample - loss: 4.8278e-09 - binary_accuracy: 1.0000 - val_loss: 1.1554 - val_binary_accuracy: 0.8207
# Epoch 47/50
# 10000/10000 [==============================] - 3s 287us/sample - loss: 4.9125e-09 - binary_accuracy: 1.0000 - val_loss: 1.1570 - val_binary_accuracy: 0.8210
# Epoch 48/50
# 10000/10000 [==============================] - 3s 291us/sample - loss: 4.7730e-09 - binary_accuracy: 1.0000 - val_loss: 1.1581 - val_binary_accuracy: 0.8210
# Epoch 49/50
# 10000/10000 [==============================] - 3s 296us/sample - loss: 4.8120e-09 - binary_accuracy: 1.0000 - val_loss: 1.1573 - val_binary_accuracy: 0.8213
# Epoch 50/50
# 10000/10000 [==============================] - 3s 274us/sample - loss: 4.7186e-09 - binary_accuracy: 1.0000 - val_loss: 1.1586 - val_binary_accuracy: 0.8215
# CPU times: user 6min 39s, sys: 1min 47s, total: 8min 27s
# Wall time: 2min 29s

# %%
# 테스트 데이터 토큰화

test_dir = os.path.join(imdb_dir, 'test')

labels = []
texts = []

for label_type in ['neg', 'pos']:
    dir_name = os.path.join(test_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname[-4:] == '.txt':
            f = open(os.path.join(dir_name, fname), encoding = "utf8")
            texts.append(f.read())
            f.close()
            if label_type == 'neg':
                labels.append(0)
            else:
                labels.append(1)
                
sequences = tokenizer.texts_to_sequences(texts)
x_test = pad_sequences(sequences, maxlen = maxlen)
y_test = np.asarray(labels)

# 테스트 세트에서 모델 평가
model.load_weights('pre_trained_glove_model.h5')
model.evaluate(x_test, y_test)
# Out:
# 25000/25000 [==============================] - 1s 21us/sample - loss: 4.6029 - binary_accuracy: 0.6889
# [4.6028896128082275, 0.68888]
